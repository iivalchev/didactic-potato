# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report

print("TensorFlow version:", tf.__version__)

gpus = tf.config.list_physical_devices("GPU")
print("GPUs found:", gpus)

if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print("✅ GPU е наличен и memory growth е включен.")
else:
    print("❌ TensorFlow не вижда GPU. Ще тренира на CPU.")
# Out:
# TensorFlow version: 2.10.0
# GPUs found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ GPU е наличен и memory growth е включен.

# %%
DATASET_CSV = r"D:\Магистър\Общ проект\dataset_mri_pet_labels.csv"

dataset_df = pd.read_csv(DATASET_CSV)

print("Dataset shape:", dataset_df.shape)
display(dataset_df.head())

print("Разпределение по диагноза:")
print(dataset_df["diagnosis"].value_counts())
# Out:
# Dataset shape: (458, 5)
#    subject_id                                           mri_path  \
# 0  002_S_0295  D:\Магистър\Общ проект\ADNI_tensors_complete\0...
# 1  002_S_0413  D:\Магистър\Общ проект\ADNI_tensors_complete\0...
# 2  002_S_0685  D:\Магистър\Общ проект\ADNI_tensors_complete\0...
# 3  002_S_1261  D:\Магистър\Общ проект\ADNI_tensors_complete\0...
# 4  002_S_1280  D:\Магистър\Общ проект\ADNI_tensors_complete\0...
#
#                                             pet_path diagnosis  label
# 0  D:\Магистър\Общ проект\ADNI_tensors_complete\0...        CN      0
# 1  D:\Магистър\Общ проект\ADNI_tensors_complete\0...        CN      0
# 2  D:\Магистър\Общ проект\ADNI_tensors_complete\0...        CN      0
# 3  D:\Магистър\Общ проект\ADNI_tensors_complete\0...        CN      0
# 4  D:\Магистър\Общ проект\ADNI_tensors_complete\0...        CN      0
# Разпределение по диагноза:
# diagnosis
# CN    311
# AD    147
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_val_df, test_df = train_test_split(
    dataset_df,
    test_size=0.20,
    random_state=42,
    stratify=dataset_df["label"]
)

train_df, val_df = train_test_split(
    train_val_df,
    test_size=0.20,
    random_state=42,
    stratify=train_val_df["label"]
)

print("Train:", len(train_df))
print(train_df["diagnosis"].value_counts())
print()

print("Validation:", len(val_df))
print(val_df["diagnosis"].value_counts())
print()

print("Test:", len(test_df))
print(test_df["diagnosis"].value_counts())
# Out:
# Train: 292
# diagnosis
# CN    199
# AD     93
# Name: count, dtype: int64
#
# Validation: 74
# diagnosis
# CN    50
# AD    24
# Name: count, dtype: int64
#
# Test: 92
# diagnosis
# CN    62
# AD    30
# Name: count, dtype: int64

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = np.array([0, 1])  # CN = 0, AD = 1

class_weights_values = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=train_df["label"].values
)

class_weights = {
    0: class_weights_values[0],
    1: class_weights_values[1]
}

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 0.7336683417085427, 1: 1.5698924731182795}

# %%
import tensorflow as tf
import numpy as np

BATCH_SIZE = 2
INPUT_SHAPE = (64, 64, 64, 2)

def downsample_volume(volume):
    """
    Намалява 128x128x128 до 64x64x64 чрез вземане на всяка втора стойност.
    """
    return volume[::2, ::2, ::2]

def load_sample(mri_path, pet_path, label):
    mri_path = mri_path.decode("utf-8")
    pet_path = pet_path.decode("utf-8")

    mri = np.load(mri_path).astype("float32")
    pet = np.load(pet_path).astype("float32")

    mri = downsample_volume(mri)
    pet = downsample_volume(pet)

    # MRI и PET като два канала
    x = np.stack([mri, pet], axis=-1)

    y = np.float32(label)

    return x, y

def tf_load_sample(mri_path, pet_path, label):
    x, y = tf.numpy_function(
        load_sample,
        [mri_path, pet_path, label],
        [tf.float32, tf.float32]
    )

    x.set_shape(INPUT_SHAPE)
    y.set_shape(())

    return x, y

def make_dataset(df, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((
        df["mri_path"].values,
        df["pet_path"].values,
        df["label"].values.astype("float32")
    ))

    if shuffle:
        ds = ds.shuffle(
            buffer_size=len(df),
            seed=42,
            reshuffle_each_iteration=True
        )

    ds = ds.map(tf_load_sample, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

train_ds = make_dataset(train_df, shuffle=True)
val_ds = make_dataset(val_df)
test_ds = make_dataset(test_df)

print("✅ TensorFlow datasets са готови.")

for x_batch, y_batch in train_ds.take(1):
    print("X batch shape:", x_batch.shape)
    print("Y batch shape:", y_batch.shape)
# Out:
# ✅ TensorFlow datasets са готови.
# X batch shape: (2, 64, 64, 64, 2)
# Y batch shape: (2,)

# %%
from tensorflow.keras import layers, models, regularizers

def residual_block_3d(x, filters, stride=1, name=None):
    shortcut = x

    x = layers.Conv3D(
        filters,
        kernel_size=3,
        strides=stride,
        padding="same",
        use_bias=False,
        name=None if name is None else name + "_conv1"
    )(x)
    x = layers.BatchNormalization(name=None if name is None else name + "_bn1")(x)
    x = layers.Activation("relu", name=None if name is None else name + "_relu1")(x)

    x = layers.Conv3D(
        filters,
        kernel_size=3,
        strides=1,
        padding="same",
        use_bias=False,
        name=None if name is None else name + "_conv2"
    )(x)
    x = layers.BatchNormalization(name=None if name is None else name + "_bn2")(x)

    if shortcut.shape[-1] != filters or stride != 1:
        shortcut = layers.Conv3D(
            filters,
            kernel_size=1,
            strides=stride,
            padding="same",
            use_bias=False,
            name=None if name is None else name + "_shortcut_conv"
        )(shortcut)
        shortcut = layers.BatchNormalization(
            name=None if name is None else name + "_shortcut_bn"
        )(shortcut)

    x = layers.Add(name=None if name is None else name + "_add")([x, shortcut])
    x = layers.Activation("relu", name=None if name is None else name + "_relu_out")(x)

    return x


def build_small_3d_resnet_classifier(input_shape=(64, 64, 64, 2)):
    inputs = layers.Input(shape=input_shape, name="mri_pet_input")

    # Stem
    x = layers.Conv3D(
        16,
        kernel_size=3,
        strides=1,
        padding="same",
        use_bias=False,
        name="stem_conv"
    )(inputs)
    x = layers.BatchNormalization(name="stem_bn")(x)
    x = layers.Activation("relu", name="stem_relu")(x)
    x = layers.MaxPooling3D(pool_size=2, name="stem_pool")(x)  # 32x32x32

    # Малък ResNet backbone
    x = residual_block_3d(x, 16, stride=1, name="res_block_1")  # 32
    x = residual_block_3d(x, 32, stride=2, name="res_block_2")  # 16
    x = residual_block_3d(x, 64, stride=2, name="res_block_3")  # 8

    x = layers.GlobalAveragePooling3D(name="global_avg_pool")(x)

    x = layers.Dense(
        32,
        activation="relu",
        kernel_regularizer=regularizers.l2(1e-4),
        name="dense_32"
    )(x)
    x = layers.Dropout(0.5, name="dropout")(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid",
        name="classification_output"
    )(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="Model1_Small_3D_ResNet_AD_CN"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=[
            tf.keras.metrics.BinaryAccuracy(name="accuracy"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="sensitivity"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    return model

model1 = build_small_3d_resnet_classifier()
model1.summary()
# Out:
# Model: "Model1_Small_3D_ResNet_AD_CN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  mri_pet_input (InputLayer)     [(None, 64, 64, 64,  0           []
#                                  2)]
#
#  stem_conv (Conv3D)             (None, 64, 64, 64,   864         ['mri_pet_input[0][0]']
#                                 16)
#
#  stem_bn (BatchNormalization)   (None, 64, 64, 64,   64          ['stem_conv[0][0]']
#                                 16)
#
#  stem_relu (Activation)         (None, 64, 64, 64,   0           ['stem_bn[0][0]']
#                                 16)
#
#  stem_pool (MaxPooling3D)       (None, 32, 32, 32,   0           ['stem_relu[0][0]']
#                                 16)
#
#  res_block_1_conv1 (Conv3D)     (None, 32, 32, 32,   6912        ['stem_pool[0][0]']
#                                 16)
#
#  res_block_1_bn1 (BatchNormaliz  (None, 32, 32, 32,   64         ['res_block_1_conv1[0][0]']
#  ation)                         16)
#
#  res_block_1_relu1 (Activation)  (None, 32, 32, 32,   0          ['res_block_1_bn1[0][0]']
#                                 16)
#
#  res_block_1_conv2 (Conv3D)     (None, 32, 32, 32,   6912        ['res_block_1_relu1[0][0]']
#                                 16)
#
#  res_block_1_bn2 (BatchNormaliz  (None, 32, 32, 32,   64         ['res_block_1_conv2[0][0]']
#  ation)                         16)
#
#  res_block_1_add (Add)          (None, 32, 32, 32,   0           ['res_block_1_bn2[0][0]',
#                                 16)                               'stem_pool[0][0]']
#
#  res_block_1_relu_out (Activati  (None, 32, 32, 32,   0          ['res_block_1_add[0][0]']
#  on)                            16)
#
#  res_block_2_conv1 (Conv3D)     (None, 16, 16, 16,   13824       ['res_block_1_relu_out[0][0]']
#                                 32)
#
#  res_block_2_bn1 (BatchNormaliz  (None, 16, 16, 16,   128        ['res_block_2_conv1[0][0]']
#  ation)                         32)
#
#  res_block_2_relu1 (Activation)  (None, 16, 16, 16,   0          ['res_block_2_bn1[0][0]']
#                                 32)
#
#  res_block_2_conv2 (Conv3D)     (None, 16, 16, 16,   27648       ['res_block_2_relu1[0][0]']
#                                 32)
#
#  res_block_2_shortcut_conv (Con  (None, 16, 16, 16,   512        ['res_block_1_relu_out[0][0]']
#  v3D)                           32)
#
#  res_block_2_bn2 (BatchNormaliz  (None, 16, 16, 16,   128        ['res_block_2_conv2[0][0]']
#  ation)                         32)
#
#  res_block_2_shortcut_bn (Batch  (None, 16, 16, 16,   128        ['res_block_2_shortcut_conv[0][0]
#  Normalization)                 32)                              ']
#
#  res_block_2_add (Add)          (None, 16, 16, 16,   0           ['res_block_2_bn2[0][0]',
#                                 32)                               'res_block_2_shortcut_bn[0][0]']
#
#  res_block_2_relu_out (Activati  (None, 16, 16, 16,   0          ['res_block_2_add[0][0]']
#  on)                            32)
#
#  res_block_3_conv1 (Conv3D)     (None, 8, 8, 8, 64)  55296       ['res_block_2_relu_out[0][0]']
#
#  res_block_3_bn1 (BatchNormaliz  (None, 8, 8, 8, 64)  256        ['res_block_3_conv1[0][0]']
#  ation)
#
#  res_block_3_relu1 (Activation)  (None, 8, 8, 8, 64)  0          ['res_block_3_bn1[0][0]']
#
#  res_block_3_conv2 (Conv3D)     (None, 8, 8, 8, 64)  110592      ['res_block_3_relu1[0][0]']
#
#  res_block_3_shortcut_conv (Con  (None, 8, 8, 8, 64)  2048       ['res_block_2_relu_out[0][0]']
#  v3D)
#
#  res_block_3_bn2 (BatchNormaliz  (None, 8, 8, 8, 64)  256        ['res_block_3_conv2[0][0]']
#  ation)
#
#  res_block_3_shortcut_bn (Batch  (None, 8, 8, 8, 64)  256        ['res_block_3_shortcut_conv[0][0]
#  Normalization)                                                  ']
#
#  res_block_3_add (Add)          (None, 8, 8, 8, 64)  0           ['res_block_3_bn2[0][0]',
#                                                                   'res_block_3_shortcut_bn[0][0]']
#
#  res_block_3_relu_out (Activati  (None, 8, 8, 8, 64)  0          ['res_block_3_add[0][0]']
#  on)
#
#  global_avg_pool (GlobalAverage  (None, 64)          0           ['res_block_3_relu_out[0][0]']
#  Pooling3D)
#
#  dense_32 (Dense)               (None, 32)           2080        ['global_avg_pool[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense_32[0][0]']
#
#  classification_output (Dense)  (None, 1)            33          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 228,065
# Trainable params: 227,393
# Non-trainable params: 672
# __________________________________________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "model1_small_3d_resnet.keras",
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-7,
        verbose=1
    )
]

# %%
history1 = model1.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 146/146 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.5240 - precision: 0.3506 - sensitivity: 0.5806 - auc: 0.5194
# Epoch 1: val_loss improved from inf to 0.76733, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 19s 96ms/step - loss: 0.7225 - accuracy: 0.5240 - precision: 0.3506 - sensitivity: 0.5806 - auc: 0.5194 - val_loss: 0.7673 - val_accuracy: 0.3243 - val_precision: 0.3243 - val_sensitivity: 1.0000 - val_auc: 0.6242 - lr: 1.0000e-04
# Epoch 2/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.5582 - precision: 0.3875 - sensitivity: 0.6667 - auc: 0.6125
# Epoch 2: val_loss did not improve from 0.76733
# 146/146 [==============================] - 13s 92ms/step - loss: 0.6813 - accuracy: 0.5582 - precision: 0.3875 - sensitivity: 0.6667 - auc: 0.6125 - val_loss: 0.7843 - val_accuracy: 0.3243 - val_precision: 0.3243 - val_sensitivity: 1.0000 - val_auc: 0.7625 - lr: 1.0000e-04
# Epoch 3/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6977 - accuracy: 0.5308 - precision: 0.3608 - sensitivity: 0.6129 - auc: 0.5731
# Epoch 3: val_loss improved from 0.76733 to 0.66916, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6977 - accuracy: 0.5308 - precision: 0.3608 - sensitivity: 0.6129 - auc: 0.5731 - val_loss: 0.6692 - val_accuracy: 0.6622 - val_precision: 0.4878 - val_sensitivity: 0.8333 - val_auc: 0.7675 - lr: 1.0000e-04
# Epoch 4/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.5548 - precision: 0.3879 - sensitivity: 0.6882 - auc: 0.6184
# Epoch 4: val_loss improved from 0.66916 to 0.61019, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6813 - accuracy: 0.5548 - precision: 0.3879 - sensitivity: 0.6882 - auc: 0.6184 - val_loss: 0.6102 - val_accuracy: 0.7973 - val_precision: 0.6800 - val_sensitivity: 0.7083 - val_auc: 0.8242 - lr: 1.0000e-04
# Epoch 5/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.5514 - precision: 0.3908 - sensitivity: 0.7312 - auc: 0.6381
# Epoch 5: val_loss did not improve from 0.61019
# 146/146 [==============================] - 13s 91ms/step - loss: 0.6666 - accuracy: 0.5514 - precision: 0.3908 - sensitivity: 0.7312 - auc: 0.6381 - val_loss: 0.6434 - val_accuracy: 0.6757 - val_precision: 0.5000 - val_sensitivity: 0.8333 - val_auc: 0.7917 - lr: 1.0000e-04
# Epoch 6/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6317 - accuracy: 0.6301 - precision: 0.4460 - sensitivity: 0.6667 - auc: 0.6967
# Epoch 6: val_loss did not improve from 0.61019
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 146/146 [==============================] - 13s 91ms/step - loss: 0.6317 - accuracy: 0.6301 - precision: 0.4460 - sensitivity: 0.6667 - auc: 0.6967 - val_loss: 0.6479 - val_accuracy: 0.7297 - val_precision: 0.5500 - val_sensitivity: 0.9167 - val_auc: 0.8383 - lr: 1.0000e-04
# Epoch 7/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.6712 - precision: 0.4874 - sensitivity: 0.6237 - auc: 0.6895
# Epoch 7: val_loss improved from 0.61019 to 0.57831, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6390 - accuracy: 0.6712 - precision: 0.4874 - sensitivity: 0.6237 - auc: 0.6895 - val_loss: 0.5783 - val_accuracy: 0.7568 - val_precision: 0.5938 - val_sensitivity: 0.7917 - val_auc: 0.8188 - lr: 5.0000e-05
# Epoch 8/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6446 - accuracy: 0.6507 - precision: 0.4662 - sensitivity: 0.6667 - auc: 0.6886
# Epoch 8: val_loss improved from 0.57831 to 0.56419, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6446 - accuracy: 0.6507 - precision: 0.4662 - sensitivity: 0.6667 - auc: 0.6886 - val_loss: 0.5642 - val_accuracy: 0.7432 - val_precision: 0.5806 - val_sensitivity: 0.7500 - val_auc: 0.8221 - lr: 5.0000e-05
# Epoch 9/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6424 - accuracy: 0.6849 - precision: 0.5038 - sensitivity: 0.7097 - auc: 0.7049
# Epoch 9: val_loss improved from 0.56419 to 0.54106, saving model to model1_small_3d_resnet.keras
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6424 - accuracy: 0.6849 - precision: 0.5038 - sensitivity: 0.7097 - auc: 0.7049 - val_loss: 0.5411 - val_accuracy: 0.7568 - val_precision: 0.6154 - val_sensitivity: 0.6667 - val_auc: 0.8375 - lr: 5.0000e-05
# Epoch 10/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6491 - accuracy: 0.6336 - precision: 0.4485 - sensitivity: 0.6559 - auc: 0.6748
# Epoch 10: val_loss did not improve from 0.54106
# 146/146 [==============================] - 13s 92ms/step - loss: 0.6491 - accuracy: 0.6336 - precision: 0.4485 - sensitivity: 0.6559 - auc: 0.6748 - val_loss: 0.5501 - val_accuracy: 0.7838 - val_precision: 0.6667 - val_sensitivity: 0.6667 - val_auc: 0.8204 - lr: 5.0000e-05
# Epoch 11/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.6370 - precision: 0.4511 - sensitivity: 0.6452 - auc: 0.7039
# Epoch 11: val_loss did not improve from 0.54106
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 146/146 [==============================] - 14s 92ms/step - loss: 0.6334 - accuracy: 0.6370 - precision: 0.4511 - sensitivity: 0.6452 - auc: 0.7039 - val_loss: 0.5473 - val_accuracy: 0.7838 - val_precision: 0.6667 - val_sensitivity: 0.6667 - val_auc: 0.8300 - lr: 5.0000e-05
# Epoch 12/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.6507 - precision: 0.4656 - sensitivity: 0.6559 - auc: 0.7027
# Epoch 12: val_loss did not improve from 0.54106
# 146/146 [==============================] - 14s 92ms/step - loss: 0.6329 - accuracy: 0.6507 - precision: 0.4656 - sensitivity: 0.6559 - auc: 0.7027 - val_loss: 0.5818 - val_accuracy: 0.7838 - val_precision: 0.6333 - val_sensitivity: 0.7917 - val_auc: 0.8221 - lr: 2.5000e-05
# Epoch 13/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.6712 - precision: 0.4887 - sensitivity: 0.6989 - auc: 0.7206
# Epoch 13: val_loss did not improve from 0.54106
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6155 - accuracy: 0.6712 - precision: 0.4887 - sensitivity: 0.6989 - auc: 0.7206 - val_loss: 0.5417 - val_accuracy: 0.7838 - val_precision: 0.6538 - val_sensitivity: 0.7083 - val_auc: 0.8275 - lr: 2.5000e-05
# Epoch 14/30
# 146/146 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.5890 - precision: 0.4192 - sensitivity: 0.7527 - auc: 0.7028Restoring model weights from the end of the best epoch: 9.
#
# Epoch 14: val_loss did not improve from 0.54106
# 146/146 [==============================] - 14s 93ms/step - loss: 0.6359 - accuracy: 0.5890 - precision: 0.4192 - sensitivity: 0.7527 - auc: 0.7028 - val_loss: 0.5658 - val_accuracy: 0.7703 - val_precision: 0.6296 - val_sensitivity: 0.7083 - val_auc: 0.8304 - lr: 1.2500e-05
# Epoch 14: early stopping

# %%
import matplotlib.pyplot as plt

def plot_metric(history, metric, title, filename):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history[metric], label=f"Train {metric}")
    plt.plot(history.history[f"val_{metric}"], label=f"Validation {metric}")
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel(metric)
    plt.legend()
    plt.grid(True)
    plt.savefig(filename, dpi=150, bbox_inches="tight")
    plt.show()

plot_metric(history1, "accuracy", "Model 1 - Accuracy", "model1_accuracy.png")
plot_metric(history1, "loss", "Model 1 - Loss", "model1_loss.png")
plot_metric(history1, "precision", "Model 1 - Precision", "model1_precision.png")
plot_metric(history1, "sensitivity", "Model 1 - Sensitivity", "model1_sensitivity.png")
plot_metric(history1, "auc", "Model 1 - AUC", "model1_auc.png")

# %%
test_results = model1.evaluate(test_ds, verbose=1)

print("Test results:")
for name, value in zip(model1.metrics_names, test_results):
    print(f"{name}: {value:.4f}")
# Out:
# 46/46 [==============================] - 2s 30ms/step - loss: 0.6142 - accuracy: 0.6848 - precision: 0.5217 - sensitivity: 0.4000 - auc: 0.6642
# Test results:
# loss: 0.6142
# accuracy: 0.6848
# precision: 0.5217
# sensitivity: 0.4000
# auc: 0.6642

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

y_true = []
y_prob = []

for x_batch, y_batch in test_ds:
    preds = model1.predict(x_batch, verbose=0)
    y_prob.extend(preds.ravel())
    y_true.extend(y_batch.numpy().ravel())

y_true = np.array(y_true).astype(int)
y_prob = np.array(y_prob)

y_pred = (y_prob >= 0.5).astype(int)

cm = confusion_matrix(y_true, y_pred)

tn, fp, fn, tp = cm.ravel()

print("Confusion Matrix:")
print(cm)
print()
print(f"TN: {tn}")
print(f"FP: {fp}")
print(f"FN: {fn}")
print(f"TP: {tp}")
print()

print(classification_report(
    y_true,
    y_pred,
    target_names=["CN", "AD"]
))
# Out:
# Confusion Matrix:
# [[51 11]
#  [18 12]]
#
# TN: 51
# FP: 11
# FN: 18
# TP: 12
#
#               precision    recall  f1-score   support
#
#           CN       0.74      0.82      0.78        62
#           AD       0.52      0.40      0.45        30
#
#     accuracy                           0.68        92
#    macro avg       0.63      0.61      0.62        92
# weighted avg       0.67      0.68      0.67        92

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Predicted CN", "Predicted AD"],
    yticklabels=["Real CN", "Real AD"]
)

plt.title("Model 1 - 3D ResNet-like Confusion Matrix")
plt.ylabel("Real label")
plt.xlabel("Predicted label")
plt.tight_layout()
plt.savefig("model1_confusion_matrix.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
test_results = model1.evaluate(test_ds, verbose=1)

print("Test results:")
for name, value in zip(model1.metrics_names, test_results):
    print(f"{name}: {value:.4f}")
# Out:
# 46/46 [==============================] - 2s 29ms/step - loss: 0.6142 - accuracy: 0.6848 - precision: 0.5217 - sensitivity: 0.4000 - auc: 0.6642
# Test results:
# loss: 0.6142
# accuracy: 0.6848
# precision: 0.5217
# sensitivity: 0.4000
# auc: 0.6642

# %%
model1_results = {
    "model": "Model 2 - 3D ResNet-like MRI/PET Classifier",
    "test_loss": test_results[0],
    "test_accuracy": test_results[1],
    "test_precision": test_results[2],
    "test_sensitivity": test_results[3],
    "test_auc": test_results[4],
    "TN": tn,
    "FP": fp,
    "FN": fn,
    "TP": tp
}

model1_results_df = pd.DataFrame([model1_results])

display(model1_results_df)

model1_results_df.to_csv("model2_results.csv", index=False)

print("💾 Запазено: model2_results.csv")
# Out:
#                                          model  test_loss  test_accuracy  \
# 0  Model 2 - 3D ResNet-like MRI/PET Classifier    0.61418       0.684783
#
#    test_precision  test_sensitivity  test_auc  TN  FP  FN  TP
# 0        0.521739               0.4  0.664247  51  11  18  12
# 💾 Запазено: model2_results.csv
